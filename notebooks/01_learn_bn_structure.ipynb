# %% [markdown]
# # Bayesian Network Structure Learning for OCD Treatment
#
# This notebook demonstrates:
# - Loading preprocessed OCD treatment data
# - Learning Bayesian network structure using K2 algorithm (Algorithm 5.2-5.3)
# - Learning structure using Local Search (Algorithm 5.4)
# - Computing sufficient statistics (Algorithm 4.1)
# - Parameter learning using MLE and EM (Section 4.4.2)
# - Inference and prediction
